# %%
# PRÁCTICA 5: IMPLEMENTACIÓN DE DEEP LEARNING EN TAREAS DE RECONOCIMIENTO DE IMÁGENES


import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

clases = [
    "Avión",
    "Automóvil",
    "Ave",
    "Gato",
    "Venado",
    "Perro",
    "Rana",
    "Caballo",
    "Barco",
    "Camión"
]

plt.figure(figsize=(10, 5))

for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_train[i])
    plt.title(clases[y_train[i][0]])
    plt.axis("off")

plt.show()

print("Forma de X_train:", X_train.shape)
print("Forma de y_train:", y_train.shape)
print("Forma de X_test:", X_test.shape)
print("Forma de y_test:", y_test.shape)

X_train = X_train.astype("float32") / 255.0
X_test = X_test.astype("float32") / 255.0

y_train_cat = to_categorical(y_train, 10)
y_test_cat = to_categorical(y_test, 10)

modelo = Sequential()

modelo.add(Conv2D(
    filters=32,
    kernel_size=(3, 3),
    activation="relu",
    input_shape=(32, 32, 3)
))

modelo.add(MaxPooling2D(pool_size=(2, 2)))

modelo.add(Conv2D(
    filters=64,
    kernel_size=(3, 3),
    activation="relu"
))

modelo.add(MaxPooling2D(pool_size=(2, 2)))

modelo.add(Flatten())

modelo.add(Dense(128, activation="relu"))

modelo.add(Dropout(0.5))

modelo.add(Dense(10, activation="softmax"))

modelo.summary()

modelo.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

historial = modelo.fit(
    X_train,
    y_train_cat,
    epochs=10,
    batch_size=64,
    validation_split=0.2
)

perdida, exactitud = modelo.evaluate(X_test, y_test_cat)

print("Pérdida en prueba:", perdida)
print("Exactitud en prueba:", exactitud)

plt.plot(
    historial.history["accuracy"],
    label="Exactitud de entrenamiento"
)

plt.plot(
    historial.history["val_accuracy"],
    label="Exactitud de validación"
)

plt.title("Exactitud durante el entrenamiento")
plt.xlabel("Épocas")
plt.ylabel("Exactitud")
plt.legend()
plt.grid(True)
plt.show()

plt.plot(
    historial.history["loss"],
    label="Pérdida de entrenamiento"
)

plt.plot(
    historial.history["val_loss"],
    label="Pérdida de validación"
)

plt.title("Pérdida durante el entrenamiento")
plt.xlabel("Épocas")
plt.ylabel("Pérdida")
plt.legend()
plt.grid(True)
plt.show()

predicciones = modelo.predict(X_test)

plt.figure(figsize=(12, 6))

for i in range(10):

    clase_real = y_test[i][0]
    clase_predicha = np.argmax(predicciones[i])

    plt.subplot(2, 5, i + 1)

    plt.imshow(X_test[i])

    plt.title(
        "Real: " + clases[clase_real] +
        "\nPred: " + clases[clase_predicha]
    )

    plt.axis("off")

plt.show()

indice = 25

imagen = X_test[indice]

imagen_expandida = np.expand_dims(imagen, axis=0)

prediccion = modelo.predict(imagen_expandida)

clase_predicha = np.argmax(prediccion)

clase_real = y_test[indice][0]

plt.imshow(imagen)

plt.title(
    "Clase real: " + clases[clase_real] +
    "\nClase predicha: " + clases[clase_predicha]
)

plt.axis("off")

plt.show()

print("Probabilidades por clase:")

for i in range(10):
    print(clases[i], ":", prediccion[0][i])
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787600158.472340   12147 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1787600175.825639   12147 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787600188.055817   12147 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 1790s 10us/step
# Forma de X_train: (50000, 32, 32, 3)
# Forma de y_train: (50000, 1)
# Forma de X_test: (10000, 32, 32, 3)
# Forma de y_test: (10000, 1)
# /usr/local/python/3.12.1/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1787601994.331077   12147 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 315,722 (1.20 MB)
#  Trainable params: 315,722 (1.20 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# W0000 00:00:1787601995.160786   12147 cpu_allocator_impl.cc:82] Allocation of 491520000 exceeds 10% of free system memory.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3547 - loss: 1.7477
# W0000 00:00:1787602027.932448   12147 cpu_allocator_impl.cc:82] Allocation of 122880000 exceeds 10% of free system memory.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.3547 - loss: 1.7477 - val_accuracy: 0.4920 - val_loss: 1.4636
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.4884 - loss: 1.4226 - val_accuracy: 0.5717 - val_loss: 1.2198
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 49ms/step - accuracy: 0.5407 - loss: 1.2862 - val_accuracy: 0.5916 - val_loss: 1.1835
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 31s 49ms/step - accuracy: 0.5754 - loss: 1.1974 - val_accuracy: 0.6208 - val_loss: 1.0708
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 30s 48ms/step - accuracy: 0.6039 - loss: 1.1331 - val_accuracy: 0.6152 - val_loss: 1.0986
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 31s 49ms/step - accuracy: 0.6196 - loss: 1.0788 - val_accuracy: 0.6506 - val_loss: 1.0060
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 46s 57ms/step - accuracy: 0.6377 - loss: 1.0284 - val_accuracy: 0.6469 - val_loss: 1.0031
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 39s 54ms/step - accuracy: 0.6514 - loss: 0.9886 - val_accuracy: 0.6608 - val_loss: 0.9628
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 37s 48ms/step - accuracy: 0.6604 - loss: 0.9534 - val_accuracy: 0.6760 - val_loss: 0.9418
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 48ms/step - accuracy: 0.6740 - loss: 0.9257 - val_accuracy: 0.6843 - val_loss: 0.9060
#  21/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7054 - loss: 0.8593
# W0000 00:00:1787602365.198665   12147 cpu_allocator_impl.cc:82] Allocation of 122880000 exceeds 10% of free system memory.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6884 - loss: 0.9135
# Pérdida en prueba: 0.913490355014801
# Exactitud en prueba: 0.6883999705314636
#   5/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step
# W0000 00:00:1787602371.040948   12147 cpu_allocator_impl.cc:82] Allocation of 122880000 exceeds 10% of free system memory.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Probabilidades por clase:
# Avión : 0.0012313287
# Automóvil : 0.00027885797
# Ave : 0.2752988
# Gato : 0.082747705
# Venado : 0.47058275
# Perro : 0.03998705
# Rana : 0.113022745
# Caballo : 0.014969956
# Barco : 0.0007191522
# Camión : 0.0011616611
